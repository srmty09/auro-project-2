# %% [markdown]
# # 🚀 Odia-English Translation Model Tester
#
# This notebook helps you test your trained mT5 model for Odia-English translation.
#
# ## 📋 Instructions:
# 1. **Upload your model**: Upload `best_model.pt` to this Colab session
# 2. **Run the cells**: Execute each cell in order
# 3. **See results**: View translation examples and quality scores
# 4. **Try interactive mode**: Test with your own Odia text
#
# ---
